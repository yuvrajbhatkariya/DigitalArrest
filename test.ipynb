# %%
print("hi")
# Out:
# hi

# %%
import google.generativeai as genai
import os
from dotenv import load_dotenv

load_dotenv()
genai.configure(api_key=os.getenv("GEMINI_API_KEY"))

for m in genai.list_models():
    print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/deep-research-pro-preview-12-2025
# models/gemini-embedding-001
# models/gemini-embedding-2-preview
# models/aqa
# models/imagen-4.0-generate-001
# models/imagen-4.0-ultra-generate-001
# models/imagen-4.0-fast-generate-001
# models/veo-2.0-generate-001
# models/veo-3.0-generate-001
# models/veo-3.0-fast-generate-001
# models/veo-3.1-generate-preview
# models/veo-3.1-fast-generate-preview
# models/veo-3.1-lite-generate-preview
# models/gemini-2.5-flash-native-audio-latest
# models/gemini-2.5-flash-native-audio-preview-09-2025
# models/gemini-2.5-flash-native-audio-preview-12-2025
# models/gemini-3.1-flash-live-preview

# %%
import os
from dotenv import load_dotenv
import google.generativeai as genai

load_dotenv()

genai.configure(api_key=os.getenv("GEMINI_API_KEY"))

model = genai.GenerativeModel("models/gemini-2.5-flash")

response = model.generate_content("Explain fraud detection simply")

print(response.text)
# Out:
# Imagine **fraud detection** like having a really smart security guard for your money, your online accounts, or your business.
#
# Its job is to **spot unusual or suspicious activities** that might mean someone is trying to cheat or trick you, or the system.
#
# Here's how it works simply:
#
# 1.  **Learns "Normal":** It watches what you (or most people) usually do. Where do you typically shop? How much do you usually spend? When do you normally log in? This builds a picture of your "normal" behavior.
#
# 2.  **Looks for "Abnormal":** Then, it constantly compares new activities to that "normal" picture.
#     *   **Example 1 (Credit Card):** If you usually buy groceries in your hometown and suddenly a large, expensive purchase is attempted online from a country you've never visited, that's "abnormal."
#     *   **Example 2 (Online Shopping):** If someone tries to make 20 purchases from the same online store using 20 different credit cards in 5 minutes, that's "abnormal" for a typical shopper.
#     *   **Example 3 (Logging In):** If you normally log into your bank from your home computer, but suddenly someone tries to log in from a brand new device in a different country, that's "abnormal."
#
# 3.  **Raises a Flag:** When it spots something that's very different from "normal" – something that fits the profile of known fraudulent activities – it raises a red flag.
#
# 4.  **Takes Action:** Depending on how suspicious it is, it might:
#     *   **Block the transaction:** Stop the purchase from going through.
#     *   **Ask for verification:** Send you a text or email to confirm if it's really you.
#     *   **Notify a human:** Alert a fraud analyst to investigate further.
#
# **In short:** Fraud detection is like an **alarm system** that constantly monitors for anything that looks out of place, so it can stop cheaters before they cause harm.
