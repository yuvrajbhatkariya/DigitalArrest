# %%
print("hello")
# Out:
# hello

# %% [markdown]
# ### **Here we remoing Puntuation : -**

# %%
import re
def removing_punctuation(text):
    clean = re.sub(r'[^\w\s]', '', text)
    return clean

print(removing_punctuation("hey buddy ! how is going &&&& & / ?"))
# Out:
# hey buddy  how is going

# %% [markdown]
# ### **Assign words to no: -**

# %%
def num_asssign(tokens):
    word_to_index = {}
    index = 1

    for word in tokens:
        if word not in word_to_index:
            word_to_index[word] = index
            index = index + 1

    return word_to_index

# token = n_gram("Hey , i am here . where are you ?",6)
# assign = num_asssign(token)
# print(assign)

# %% [markdown]
# ### **N**

# %% [markdown]
# ### **Main Function : -**

# %%
def n_gram(text ,n):
    text.lower()
    text = removing_punctuation(text)
    tokens = text.split()
    assign_num = num_asssign(tokens)
    # bi_tokens = [" ".join(tokens[i:i+2]) for i in range(0, len(tokens), 2)]
    j = 0
    while(j <= n):
        tokens = [" ".join(tokens[i:i+2]) for i in range(0, len(tokens), 2)]
        assign_num
    print(assign_num)

# %%
n_gram("Hey, i am here",2)
# Out:
# ['Hey', 'i', 'am', 'here']
# {'Hey': 1, 'i': 2, 'am': 3, 'here': 4}

# %%
def num_asssign(tokens):
    word_to_index = {}
    index = 1

    for word in tokens:
        if word not in word_to_index:
            word_to_index[word] = index
            index = index + 1

    return word_to_index

token = n_gram("Hey , i am here . where are you ?",6)

assign = num_asssign(token)
print(assign)
# Out:
# {'Hey': 1, 'i': 2, 'am': 3, 'here': 4, 'where': 5, 'are': 6, 'you': 7}
